# %%
from __future__ import division

import pandas as pd
import numpy as np
#import html2text
from datetime import date
import random
import os

#Packages for pulling text data 
from urllib.request import urlopen  # the lib that handles the url stuff
from bs4 import BeautifulSoup
import pandas.io.data as web
from pandas.tseries.offsets import BDay

#Packages for text data processing
import nltk, re, pprint
#nltk.download()
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.stem import PorterStemmer

#Packages for statistical learning 
from sklearn.preprocessing import normalize as Normal
from sklearn import svm
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
import statsmodels.api as sm
from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline

import imp

import Text_Analytics as TA
# Out:
# C:\Users\ziyi\Anaconda3\lib\site-packages\pandas\io\data.py:35: FutureWarning:
# The pandas.io.data module is moved to a separate package (pandas-datareader) and will be removed from pandas in a future version.
# After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
#   FutureWarning)

# %%
#from imp import reload 
imp.reload(TA)
# Out:
# <module 'Text_Analytics' from 'C:\\Users\\ziyi\\Desktop\\Inde project\\Independent Study Anseri-20170120T004329Z\\Independent Study Anseri\\Code repo\\Text_Analytics.py'>

# %% [markdown]
# # Empirical Analysis

# %% [markdown]
# ## Volatitlity Increase Regression

# %% [markdown]
# ## Data Preparation

# %%
#Setup working directory 
os.chdir("C:/Users/ziyi/Desktop/Inde project/Independent Study Anseri-20170120T004329Z/Independent Study Anseri")

#Setup Item Parameters 
Item="2.02"
item="ITEM"+" "+Item
itemb="202"
add0='8K Data/tfidf_ITEM'+itemb+".csv"
Ykind='Vol_Ratio'

#Setup Output Parameters
addX1='8K data/ITEM'+itemb+Ykind+"_X_ts.csv" 
addX2='8K data/ITEM'+itemb+Ykind+"_X_text.csv" 
addY='8K data/ITEM'+itemb+Ykind+"_Y.csv"

# %%
#Import Data
df2=pd.read_csv("8K data/list_40.csv", index_col=0)
df=pd.read_csv(add0, index_col=0)
df['Date Filed']=df['Date Filed'].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d').date())

# %%
KA=TA.KeywordAnalyzer(df,df2)

# %%
df.head()
# Out:
#      aaron      abil  abl  absent  acceler    accept  access  accid  \
# 11     0.0  0.000000  0.0     0.0      0.0  0.024765     0.0    0.0
# 58     0.0  0.000000  0.0     0.0      0.0  0.000000     0.0    0.0
# 94     0.0  0.000000  0.0     0.0      0.0  0.000000     0.0    0.0
# 130    0.0  0.000000  0.0     0.0      0.0  0.000000     0.0    0.0
# 174    0.0  0.026094  0.0     0.0      0.0  0.021211     0.0    0.0
#
#      accompani    accord     ...      work     would  wright  write  written  \
# 11    0.029058  0.063184     ...       0.0  0.000000     0.0    0.0      0.0
# 58    0.000000  0.000000     ...       0.0  0.000000     0.0    0.0      0.0
# 94    0.000000  0.020766     ...       0.0  0.013025     0.0    0.0      0.0
# 130   0.046011  0.033349     ...       0.0  0.000000     0.0    0.0      0.0
# 174   0.000000  0.054117     ...       0.0  0.000000     0.0    0.0      0.0
#
#           www      year      CIK                Company Name  Date Filed
# 11   0.000000  0.022219  1018003            INGRAM MICRO INC  2015-02-26
# 58   0.109055  0.091905  1025996          KILROY REALTY CORP  2015-01-29
# 94   0.000000  0.007303   103730  VISHAY INTERTECHNOLOGY INC  2015-02-05
# 130  0.000000  0.035182  1038074    SILICON LABORATORIES INC  2015-02-04
# 174  0.000000  0.019031  1056696    MANHATTAN ASSOCIATES INC  2015-02-03
#
# [5 rows x 1174 columns]

# %%
df2.head()
# Out:
#              Ticker                      Name   Price
# 197   KRC UN Equity        KILROY REALTY CORP  68.580
# 388    WR UN Equity         WESTAR ENERGY INC  57.070
# 215  MANH UW Equity  MANHATTAN ASSOCIATES INC  50.210
# 20    ARW UN Equity     ARROW ELECTRONICS INC  59.300
# 132   FII UN Equity   FEDERATED INVESTORS INC  25.995

# %%
# pull stock return as label
Y=KA.get_Y(kind=Ykind)

# %% [markdown]
# #Pull stock return time series as X
# #X_ts=KA.get_TS(window=31)

# %% [markdown]
# index_lag=[0]*120
# for i in range(0,120):
#     index_lag[i]='Lag '+ str(i)
#
# X_ts=X_ts[index_lag]

# %% [markdown]
# X_ts=Normal(X_ts.iloc[:,0:100].as_matrix(),axis=0)

# %%
df_temp=df.drop(['CIK','Company Name','Date Filed'],axis=1).copy()
X_text=Normal(df_temp.as_matrix(),axis=1)

# %%
#pd.DataFrame(X_ts).to_csv(addX1)
pd.DataFrame(X_text).to_csv(addX2)
pd.DataFrame(Y).to_csv(addY)

# %%
X_text=pd.read_csv(addX2,index_col=0)
Y=pd.read_csv(addY,index_col=0)

# %%
X_text.columns=df_temp.columns

# %% [markdown]
# ## Lasso Regression

# %% [markdown]
# ## Text Only

# %%
#construct model and predict
X=X_text.as_matrix()
Y=Y.reshape(Y.shape[0],)

X_train,Y_train=TA.get_train(X,Y,1.0)
X_test=X_train
Y_test=Y_train

best_param=TA.Lasso_param(X_train,Y_train)
lasso =linear_model.Lasso(alpha=best_param)
lasso.fit(X_train,Y_train)
pred=lasso.predict(X_test)
# Out:
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0.5
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
best_param
# Out:
# 0.10000000000000001

# %%
print(lasso.coef_)
print(lasso.intercept_)
print(pred)
# Out:
# [-0. -0. -0. ..., -0. -0.  0.]
# 1.05977107938
# [ 1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108  1.05977108  1.05977108  1.05977108
#   1.05977108  1.05977108  1.05977108]

# %%
Comp=pd.DataFrame({"Y":Y_test,
                  "Pred":pred})
Comp["Error"]=abs(Comp["Y"]-Comp["Pred"])
Comp
# Out:
#          Pred         Y     Error
# 0    1.059771  0.581674  0.478097
# 1    1.059771  1.309113  0.249342
# 2    1.059771  0.776849  0.282922
# 3    1.059771  1.622265  0.562493
# 4    1.059771  1.722002  0.662231
# 5    1.059771  1.680732  0.620961
# 6    1.059771  0.722862  0.336909
# 7    1.059771  0.290401  0.769370
# 8    1.059771  0.925710  0.134061
# 9    1.059771  1.160224  0.100453
# 10   1.059771  0.752624  0.307147
# 11   1.059771  0.750213  0.309558
# 12   1.059771  1.038193  0.021578
# 13   1.059771  0.991054  0.068717
# 14   1.059771  0.533713  0.526058
# 15   1.059771  1.040080  0.019691
# 16   1.059771  0.103669  0.956102
# 17   1.059771  1.020245  0.039526
# 18   1.059771  0.918372  0.141399
# 19   1.059771  1.502463  0.442692
# 20   1.059771  2.183543  1.123772
# 21   1.059771  1.462848  0.403077
# 22   1.059771  0.736352  0.323419
# 23   1.059771  0.880328  0.179443
# 24   1.059771  1.233377  0.173606
# 25   1.059771  0.603947  0.455824
# 26   1.059771  2.462990  1.403219
# 27   1.059771  0.670342  0.389429
# 28   1.059771  1.256306  0.196535
# 29   1.059771  1.286915  0.227144
# ..        ...       ...       ...
# 279  1.059771  1.113528  0.053757
# 280  1.059771  0.922561  0.137210
# 281  1.059771  1.436683  0.376912
# 282  1.059771  0.660993  0.398778
# 283  1.059771  1.805898  0.746126
# 284  1.059771  1.314775  0.255004
# 285  1.059771  1.314775  0.255004
# 286  1.059771  0.732350  0.327421
# 287  1.059771  1.296637  0.236865
# 288  1.059771  0.610134  0.449637
# 289  1.059771  0.760659  0.299112
# 290  1.059771  1.041852  0.017919
# 291  1.059771  1.486262  0.426491
# 292  1.059771  2.529774  1.470003
# 293  1.059771  0.984407  0.075364
# 294  1.059771  0.709634  0.350137
# 295  1.059771  1.145344  0.085573
# 296  1.059771  0.647685  0.412086
# 297  1.059771  0.385842  0.673929
# 298  1.059771  0.356872  0.702900
# 299  1.059771  0.603422  0.456349
# 300  1.059771  1.142597  0.082826
# 301  1.059771  0.730574  0.329197
# 302  1.059771  1.325134  0.265363
# 303  1.059771  0.445159  0.614612
# 304  1.059771  0.305886  0.753885
# 305  1.059771  0.853634  0.206137
# 306  1.059771  1.442676  0.382905
# 307  1.059771  0.736349  0.323422
# 308  1.059771  1.099821  0.040050
#
# [309 rows x 3 columns]

# %%
plt.figure()
Comp[["Pred","Y"]].plot()

# %% [markdown]
# ## SVR Regression

# %%
X_train,Y_train=TA.get_train(X,Y,1.0)
X_test=X_train
Y_test=Y_train

best_param=TA.SVR_param(X_train,Y_train)
svr = SVR(kernel='linear',C=np.exp(best_param),epsilon=0.01)
svr.fit(X_train,Y_train)
pred=svr.predict(X_test)

# %%
coefs=svr.coef_
coefs=coefs.reshape(coefs.shape[1],)
print(svr.intercept_)
# Out:
# [ 0.97039149]

# %%
SVR_coefs=pd.DataFrame({"Weight":coefs},index=X_text.columns)
SVR_coefs["Abs_weight"]=abs(SVR_coefs["Weight"])
SVR_coefs=SVR_coefs.sort_values(["Abs_weight"],ascending=[False])
toexport=SVR_coefs[:50]
#pd.DataFrame(toexport).to_csv("8K Data\keywords_ITEM202.csv")

# %%
df[df["conditionon"]!=0][["ebitda","Company Name"]]
# Out:
#         ebitda             Company Name
# 342   0.000000  GREAT PLAINS ENERGY INC
# 787   0.096801              AARON'S INC
# 880   0.000000        NORTHWESTERN CORP
# 1239  0.000000     REGENCY CENTERS CORP
# 1316  0.000000               CIENA CORP
# 1347  0.000000   WASHINGTON FEDERAL INC
# 1412  0.000000    DENBURY RESOURCES INC
# 1691  0.000000  GREAT PLAINS ENERGY INC
# 1983  0.147500              AARON'S INC
# 2035  0.000000        NORTHWESTERN CORP
# 2237  0.000000     REGENCY CENTERS CORP
# 2300  0.000000               CIENA CORP
# 2311  0.000000   WASHINGTON FEDERAL INC
# 2372  0.000000    DENBURY RESOURCES INC
# 2537  0.000000  GREAT PLAINS ENERGY INC
# 2745  0.148976              AARON'S INC
# 2781  0.000000        NORTHWESTERN CORP
# 2969  0.000000     REGENCY CENTERS CORP
# 3012  0.000000               CIENA CORP
# 3026  0.000000   WASHINGTON FEDERAL INC
# 3048  0.000000    DENBURY RESOURCES INC
# 3173  0.000000  GREAT PLAINS ENERGY INC
# 3461  0.148287              AARON'S INC
# 3493  0.000000        NORTHWESTERN CORP
# 3694  0.000000     REGENCY CENTERS CORP
# 3739  0.000000               CIENA CORP
# 3765  0.000000   WASHINGTON FEDERAL INC
# 3779  0.000000    DENBURY RESOURCES INC
# 4126  0.000000  GREAT PLAINS ENERGY INC
# 4512  0.146103              AARON'S INC
# 4614  0.000000        NORTHWESTERN CORP
# 4978  0.000000     REGENCY CENTERS CORP
# 5047  0.000000               CIENA CORP
# 5076  0.000000   WASHINGTON FEDERAL INC
# 5116  0.000000    DENBURY RESOURCES INC
# 5370  0.000000  GREAT PLAINS ENERGY INC
# 5664  0.000000              AARON'S INC
# 5708  0.000000        NORTHWESTERN CORP
# 5923  0.000000     REGENCY CENTERS CORP
# 5970  0.000000               CIENA CORP
# 5982  0.000000   WASHINGTON FEDERAL INC
# 6017  0.000000    DENBURY RESOURCES INC
# 6177  0.000000  GREAT PLAINS ENERGY INC
# 6399  0.000000              AARON'S INC
# 6425  0.000000        NORTHWESTERN CORP
# 6582  0.000000     REGENCY CENTERS CORP
# 6639  0.000000               CIENA CORP
# 6646  0.000000   WASHINGTON FEDERAL INC
# 6674  0.000000    DENBURY RESOURCES INC

# %%
Comp=pd.DataFrame({"Y":Y_test,
                  "Pred":pred})
Comp["Error"]=abs(Comp["Y"]-Comp["Pred"])
Comp
# Out:
#          Pred         Y     Error
# 0    1.165739  0.581674  0.584065
# 1    1.193571  1.309113  0.115541
# 2    0.805543  0.776849  0.028694
# 3    1.392129  1.622265  0.230135
# 4    1.036045  1.722002  0.685957
# 5    0.976835  1.680732  0.703897
# 6    1.157380  0.722862  0.434518
# 7    0.900292  0.290401  0.609891
# 8    0.935620  0.925710  0.009910
# 9    0.947538  1.160224  0.212686
# 10   0.974225  0.752624  0.221601
# 11   1.062759  0.750213  0.312547
# 12   1.277907  1.038193  0.239715
# 13   0.956167  0.991054  0.034887
# 14   0.964579  0.533713  0.430866
# 15   1.039846  1.040080  0.000234
# 16   0.878215  0.103669  0.774546
# 17   0.964598  1.020245  0.055647
# 18   0.865132  0.918372  0.053241
# 19   1.347894  1.502463  0.154570
# 20   1.362292  2.183543  0.821251
# 21   1.111680  1.462848  0.351169
# 22   0.965362  0.736352  0.229010
# 23   0.908671  0.880328  0.028343
# 24   1.158904  1.233377  0.074473
# 25   1.023450  0.603947  0.419502
# 26   1.047485  2.462990  1.415505
# 27   0.994529  0.670342  0.324187
# 28   1.053085  1.256306  0.203221
# 29   1.077433  1.286915  0.209482
# ..        ...       ...       ...
# 279  1.059410  1.113528  0.054118
# 280  1.009676  0.922561  0.087115
# 281  0.884952  1.436683  0.551731
# 282  0.977862  0.660993  0.316868
# 283  0.865132  1.805898  0.940766
# 284  1.315685  1.314775  0.000910
# 285  1.324751  1.314775  0.009976
# 286  1.110971  0.732350  0.378621
# 287  0.984623  1.296637  0.312014
# 288  0.851678  0.610134  0.241544
# 289  1.170231  0.760659  0.409572
# 290  1.031843  1.041852  0.010010
# 291  1.041204  1.486262  0.445058
# 292  0.981107  2.529774  1.548667
# 293  0.974297  0.984407  0.010110
# 294  1.022701  0.709634  0.313066
# 295  0.973934  1.145344  0.171410
# 296  1.009483  0.647685  0.361798
# 297  0.996576  0.385842  0.610734
# 298  0.768137  0.356872  0.411265
# 299  0.781481  0.603422  0.178059
# 300  0.891042  1.142597  0.251555
# 301  1.052320  0.730574  0.321746
# 302  1.006526  1.325134  0.318608
# 303  0.940075  0.445159  0.494916
# 304  0.797483  0.305886  0.491597
# 305  1.082413  0.853634  0.228779
# 306  0.994066  1.442676  0.448610
# 307  0.819253  0.736349  0.082904
# 308  1.089801  1.099821  0.010020
#
# [309 rows x 3 columns]

# %%
plt.figure()
with pd.plot_params.use('x_compat', True):
    Comp.Pred.plot(color="b",legend=True)
    Comp.Y.plot(color="grey",legend=True)
    
plt.xlabel("Text")

# %% [markdown]
# # Sentiment Analysis - Return - To Debug

# %% [markdown]
# ## SVM (Normalized)

# %% [markdown]
# ## Data Preparation

# %%
#Setup working directory 
os.chdir("C:/Users/ziyi/Desktop/Inde project/Independent Study Anseri-20170120T004329Z/Independent Study Anseri")

#Setup Item Parameters 
Item="2.02"
item="ITEM"+" "+Item
itemb="202"
add0='8K Data/tfidf_ITEM'+itemb+".csv"
Ykind='Return'

#Setup Output Parameters
addX1='8K data/ITEM'+itemb+Ykind+"_X_ts.csv" 
addX2='8K data/ITEM'+itemb+Ykind+"_X_text.csv" 
addY='8K data/ITEM'+itemb+Ykind+"_Y.csv"

# %%
#Import Data
df2=pd.read_csv("8K data/list_40.csv", index_col=0)
df=pd.read_csv(add0, index_col=0)
df['Date Filed']=df['Date Filed'].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d').date())

# %%
KA=KeywordAnalyzer(df,df2)

# %%
df.head()
# Out:
#      aaron      abil  abl  absent  acceler    accept  access  accid  \
# 11     0.0  0.000000  0.0     0.0      0.0  0.024765     0.0    0.0
# 58     0.0  0.000000  0.0     0.0      0.0  0.000000     0.0    0.0
# 94     0.0  0.000000  0.0     0.0      0.0  0.000000     0.0    0.0
# 130    0.0  0.000000  0.0     0.0      0.0  0.000000     0.0    0.0
# 174    0.0  0.026094  0.0     0.0      0.0  0.021211     0.0    0.0
#
#      accompani    accord     ...      work     would  wright  write  written  \
# 11    0.029058  0.063184     ...       0.0  0.000000     0.0    0.0      0.0
# 58    0.000000  0.000000     ...       0.0  0.000000     0.0    0.0      0.0
# 94    0.000000  0.020766     ...       0.0  0.013025     0.0    0.0      0.0
# 130   0.046011  0.033349     ...       0.0  0.000000     0.0    0.0      0.0
# 174   0.000000  0.054117     ...       0.0  0.000000     0.0    0.0      0.0
#
#           www      year      CIK                Company Name  Date Filed
# 11   0.000000  0.022219  1018003            INGRAM MICRO INC  2015-02-26
# 58   0.109055  0.091905  1025996          KILROY REALTY CORP  2015-01-29
# 94   0.000000  0.007303   103730  VISHAY INTERTECHNOLOGY INC  2015-02-05
# 130  0.000000  0.035182  1038074    SILICON LABORATORIES INC  2015-02-04
# 174  0.000000  0.019031  1056696    MANHATTAN ASSOCIATES INC  2015-02-03
#
# [5 rows x 1174 columns]

# %%
df2.head()
# Out:
#              Ticker                      Name   Price
# 197   KRC UN Equity        KILROY REALTY CORP  68.580
# 388    WR UN Equity         WESTAR ENERGY INC  57.070
# 215  MANH UW Equity  MANHATTAN ASSOCIATES INC  50.210
# 20    ARW UN Equity     ARROW ELECTRONICS INC  59.300
# 132   FII UN Equity   FEDERATED INVESTORS INC  25.995

# %%
# pull stock return as label
Y=KA.get_Y(kind=Ykind)

# %%
Y.head()
# Out:
#        Return
# 11  -0.022485
# 58  -0.027796
# 94  -0.025344
# 130 -0.021469
# 174 -0.000755

# %%
#Pull stock return time series as X
X_ts=KA.get_TS(window=1)
X_ts.head()
# Out:
#         Lag 0
# 11   0.019029
# 58   0.017747
# 94  -0.019872
# 130 -0.002310
# 174 -0.024558

# %%
X_ts=Normal(X_ts.as_matrix(),axis=0)

# %%
df_temp=df.drop(['CIK','Company Name','Date Filed'],axis=1).copy()
X_text=Normal(df_temp.as_matrix(),axis=1)

# %%
pd.DataFrame(X_ts).to_csv(addX1)
pd.DataFrame(X_text).to_csv(addX2)
pd.DataFrame(Y).to_csv(addY)

# %%
X_ts=pd.read_csv(addX1,index_col=0)
X_text=pd.read_csv(addX2,index_col=0)
Y=pd.read_csv(addY,index_col=0)

# %%
X_text.columns=df_temp.columns

# %% [markdown]
# ### SVM Pipeline--Text Only - To Debug

# %%
def SVM_param(X_train,Y_train):

    #rough grid
    skf = StratifiedKFold(n_splits=10)
    parameters = {'C':np.exp(np.arange(-5,10,1))}
    svc = svm.SVC(kernel='linear')
    clf = GridSearchCV(svc, parameters,cv=skf)
    clf.fit(X_train, Y_train)
    best_power=np.log(clf.best_params_['C'])
    
    #fine grid
    parameters = {'C':np.exp(np.arange(best_power-0.5,best_power+0.6,0.1))}
    clf = GridSearchCV(svc, parameters,cv=skf)
    clf.fit(X_train, Y_train)
    best_power=np.log(clf.best_params_['C'])
    
    return(best_power)

# %% [markdown]
# def SVM_pipeline(X,Y, train_ratio):
#     t_sample=int(np.floor(X.shape[0]*train_ratio))
#     X_train=X[:t_sample,:]
#     Y_train=Y[:t_sample]
#     X_test=X_train
#     Y_test=Y_train
#
#     #rough grid
#     skf = StratifiedKFold(n_splits=10)
#     parameters = {'C':np.exp(np.arange(-5,10,1))}
#     svc = svm.SVC(kernel='linear')
#     clf = GridSearchCV(svc, parameters,cv=skf)
#     clf.fit(X_train, Y_train)
#     best_power=np.log(clf.best_params_['C'])
#
#     #fine grid
#     parameters = {'C':np.exp(np.arange(best_power-0.5,best_power+0.6,0.1))}
#     clf = GridSearchCV(svc, parameters,cv=skf)
#     clf.fit(X_train, Y_train)
#     best_power=np.log(clf.best_params_['C'])
#
#     #construct model and predict
#     svc = svm.SVC(kernel='linear',C=np.exp(best_power))
#     svc.fit(X_train,Y_train)
#     pred=svc.predict(X_test)
#     c_mat=confusion_matrix(Y_test, pred)
#     #auc=roc_auc_score(Y_test, pred)
#
#     return pred,c_mat

# %%
#construct model and predict
#X=X_text.as_matrix()
#Y=np.sign(Y.as_matrix().reshape(Y.shape[0],))

X_train,Y_train=get_train(X,Y,1.0)
X_test=X_train
Y_test=Y_train

best_power=SVM_param(X_train,Y_train)

svc = svm.SVC(kernel='linear',C=np.exp(best_power))
svc.fit(X_train,Y_train)
pred=svc.predict(X_test)
c_mat=confusion_matrix(Y_test, pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-4c7c9023b3e6> in <module>()
#       7 Y_test=Y_train
#       8
# ----> 9 best_power=SVM_param(X_train,Y_train)
#      10
#      11 svc = svm.SVC(kernel='linear',C=np.exp(best_power))
#
# <ipython-input-134-eb82e1029806> in SVM_param(X_train, Y_train)
#       6     svc = svm.SVC(kernel='linear')
#       7     clf = GridSearchCV(svc, parameters,cv=skf)
# ----> 8     clf.fit(X_train, Y_train)
#       9     best_power=np.log(clf.best_params_['C'])
#      10
#
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _fit(self, X, y, groups, parameter_iterable)
#     551         pre_dispatch = self.pre_dispatch
#     552
# --> 553         cv_iter = list(cv.split(X, y, groups))
#     554         out = Parallel(
#     555             n_jobs=self.n_jobs, verbose=self.verbose,
#
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#     320                                                              n_samples))
#     321
# --> 322         for train, test in super(_BaseKFold, self).split(X, y, groups):
#     323             yield train, test
#     324
#
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#      89         X, y, groups = indexable(X, y, groups)
#      90         indices = np.arange(_num_samples(X))
# ---> 91         for test_index in self._iter_test_masks(X, y, groups):
#      92             train_index = indices[np.logical_not(test_index)]
#      93             test_index = indices[test_index]
#
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in _iter_test_masks(self, X, y, groups)
#     608
#     609     def _iter_test_masks(self, X, y=None, groups=None):
# --> 610         test_folds = self._make_test_folds(X, y)
#     611         for i in range(self.n_splits):
#     612             yield test_folds == i
#
# C:\Users\ziyi\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in _make_test_folds(self, X, y, groups)
#     573             raise ValueError("All the n_groups for individual classes"
#     574                              " are less than n_splits=%d."
# --> 575                              % (self.n_splits))
#     576         if self.n_splits > min_groups:
#     577             warnings.warn(("The least populated class in y has only %d"
#
# ValueError: All the n_groups for individual classes are less than n_splits=10.

# %%
c_mat
# Out:
# array([[106,   4,  25],
#        [ 11,  24,   9],
#        [ 31,   7,  92]])

# %%
t_sample=216
Comp=pd.DataFrame({"Y":Y_test,
                  "Pred":pred})
Comp["Error"]=abs(Comp["Y"]-Comp["Pred"])
print(Comp[Comp["Error"]==0].shape[0])
print(Comp[Comp["Error"]==1].shape[0])
print(Comp[Comp["Error"]==2].shape[0])
# Out:
# 222
# 31
# 56

# %%
Comp
# Out:
#      Pred    Y  Error
# 0    -1.0 -1.0    0.0
# 1    -1.0 -1.0    0.0
# 2    -1.0 -1.0    0.0
# 3    -1.0 -1.0    0.0
# 4     1.0 -1.0    2.0
# 5     0.0  1.0    1.0
# 6     1.0  1.0    0.0
# 7     1.0  1.0    0.0
# 8     1.0  1.0    0.0
# 9    -1.0 -1.0    0.0
# 10   -1.0 -1.0    0.0
# 11    1.0 -1.0    2.0
# 12   -1.0 -1.0    0.0
# 13    1.0  1.0    0.0
# 14    1.0  1.0    0.0
# 15    1.0  1.0    0.0
# 16    1.0  1.0    0.0
# 17   -1.0 -1.0    0.0
# 18    1.0  1.0    0.0
# 19    1.0  1.0    0.0
# 20   -1.0 -1.0    0.0
# 21    1.0  1.0    0.0
# 22    0.0 -1.0    1.0
# 23    1.0  1.0    0.0
# 24   -1.0  1.0    2.0
# 25    1.0  1.0    0.0
# 26    1.0 -1.0    2.0
# 27    0.0  1.0    1.0
# 28   -1.0 -1.0    0.0
# 29    1.0  1.0    0.0
# ..    ...  ...    ...
# 279   1.0  1.0    0.0
# 280   0.0  0.0    0.0
# 281   1.0 -1.0    2.0
# 282  -1.0  1.0    2.0
# 283   1.0  0.0    1.0
# 284  -1.0 -1.0    0.0
# 285  -1.0 -1.0    0.0
# 286   1.0 -1.0    2.0
# 287   0.0  0.0    0.0
# 288  -1.0 -1.0    0.0
# 289  -1.0  0.0    1.0
# 290  -1.0 -1.0    0.0
# 291   1.0  1.0    0.0
# 292  -1.0 -1.0    0.0
# 293   0.0  0.0    0.0
# 294   0.0  0.0    0.0
# 295   0.0  0.0    0.0
# 296  -1.0 -1.0    0.0
# 297  -1.0 -1.0    0.0
# 298  -1.0  1.0    2.0
# 299  -1.0  0.0    1.0
# 300   1.0  0.0    1.0
# 301   1.0  1.0    0.0
# 302   1.0  0.0    1.0
# 303  -1.0 -1.0    0.0
# 304   0.0  0.0    0.0
# 305   0.0 -1.0    1.0
# 306   1.0  1.0    0.0
# 307  -1.0 -1.0    0.0
# 308   1.0  1.0    0.0
#
# [309 rows x 3 columns]

# %% [markdown]
# ### TS+Text

# %%
X=np.concatenate([X_ts.as_matrix(),X_text.as_matrix()],axis=1)
Y_new=np.sign(Y.as_matrix()).reshape(Y.shape[0],)

# %%
pred, c_mat=SVM_pipeline(X,Y_new, 1.0)

# %%
c_mat
# Out:
# array([[110,   3,  22],
#        [ 12,  19,  13],
#        [ 32,   6,  92]])

# %%
t_sample=216
Comp=pd.DataFrame({"Y":Y_new,
                  "Pred":pred})
Comp["Error"]=abs(Comp["Y"]-Comp["Pred"])
print(Comp[Comp["Error"]==0].shape[0])
print(Comp[Comp["Error"]==1].shape[0])
print(Comp[Comp["Error"]==2].shape[0])
# Out:
# 221
# 34
# 54

# %%
Comp
# Out:
#      Pred    Y  Error
# 0    -1.0 -1.0    0.0
# 1    -1.0 -1.0    0.0
# 2    -1.0 -1.0    0.0
# 3    -1.0 -1.0    0.0
# 4     1.0 -1.0    2.0
# 5     0.0  1.0    1.0
# 6     1.0  1.0    0.0
# 7     1.0  1.0    0.0
# 8     1.0  1.0    0.0
# 9    -1.0 -1.0    0.0
# 10   -1.0 -1.0    0.0
# 11    1.0 -1.0    2.0
# 12   -1.0 -1.0    0.0
# 13    1.0  1.0    0.0
# 14    1.0  1.0    0.0
# 15    1.0  1.0    0.0
# 16    1.0  1.0    0.0
# 17   -1.0 -1.0    0.0
# 18    1.0  1.0    0.0
# 19    1.0  1.0    0.0
# 20   -1.0 -1.0    0.0
# 21    1.0  1.0    0.0
# 22    0.0 -1.0    1.0
# 23    1.0  1.0    0.0
# 24   -1.0  1.0    2.0
# 25    1.0  1.0    0.0
# 26    1.0 -1.0    2.0
# 27    0.0  1.0    1.0
# 28   -1.0 -1.0    0.0
# 29    1.0  1.0    0.0
# ..    ...  ...    ...
# 279   1.0  1.0    0.0
# 280   0.0  0.0    0.0
# 281  -1.0 -1.0    0.0
# 282  -1.0  1.0    2.0
# 283   1.0  0.0    1.0
# 284  -1.0 -1.0    0.0
# 285  -1.0 -1.0    0.0
# 286   1.0 -1.0    2.0
# 287   0.0  0.0    0.0
# 288  -1.0 -1.0    0.0
# 289  -1.0  0.0    1.0
# 290  -1.0 -1.0    0.0
# 291   1.0  1.0    0.0
# 292  -1.0 -1.0    0.0
# 293   0.0  0.0    0.0
# 294   0.0  0.0    0.0
# 295   0.0  0.0    0.0
# 296  -1.0 -1.0    0.0
# 297  -1.0 -1.0    0.0
# 298  -1.0  1.0    2.0
# 299  -1.0  0.0    1.0
# 300   1.0  0.0    1.0
# 301   1.0  1.0    0.0
# 302   1.0  0.0    1.0
# 303  -1.0 -1.0    0.0
# 304   0.0  0.0    0.0
# 305  -1.0 -1.0    0.0
# 306   1.0  1.0    0.0
# 307  -1.0 -1.0    0.0
# 308   1.0  1.0    0.0
#
# [309 rows x 3 columns]

# %% [markdown]
# ## SVM (Non-Normalized)

# %%
X1, X2,Y= KA.prep_Classifier(normalize=False)

# %%
pd.DataFrame(X1).to_csv('X1.csv')
pd.DataFrame(X2).to_csv('X2.csv')
pd.DataFrame(Y).to_csv('Y.csv')

# %%
# Time series only
pred, c_mat, auc=SVM_pipeline(X1,Y, 0.7)

# %%
c_mat
# Out:
# array([[170,  21],
#        [ 83,  20]])

# %%
auc
# Out:
# 0.54211355665124783

# %%
# Text only
pred, c_mat, auc=SVM_pipeline(X2,Y, 0.7)

# %%
c_mat
# Out:
# array([[180,  11],
#        [ 89,  14]])

# %%
auc
# Out:
# 0.5391653535302191

# %%
#Combined
pred, c_mat, auc=SVM_pipeline(np.concatenate([X1,X2],axis=1),Y, 0.7)

# %%
c_mat
# Out:
# array([[172,  19],
#        [ 83,  20]])

# %%
auc
# Out:
# 0.54734915874548873
